# %% [markdown]
# # For Part 2. Read the cities.csv file into a DataFrame

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data_df = pd.read_csv("weather_data/clean_cities.csv")
city_data_df.head(10)
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0  Port Elizabeth      ZA  2022-06-11 18:54:19 -33.9180   25.5701
# 1        1    San Patricio      US  2022-06-11 18:55:18  28.0170  -97.5169
# 2        2          Gadwal      IN  2022-06-11 18:55:19  16.2333   77.8000
# 3        3         Qaanaaq      GL  2022-06-11 18:51:47  77.4840  -69.3632
# 4        4           Phrae      TH  2022-06-11 18:55:19  18.0833  100.0000
# 5        5           Tiksi      RU  2022-06-11 18:55:20  71.6872  128.8694
# 6        6       Cape Town      ZA  2022-06-11 18:55:21 -33.9258   18.4232
# 7        7      Codrington      AU  2022-06-11 18:55:21 -38.2667  141.9667
# 8        8           Vaini      TO  2022-06-11 18:55:22 -21.2000 -175.2000
# 9        9         Ushuaia      AR  2022-06-11 18:50:59 -54.8000  -68.3000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     62.89        59         100        3.44
# 1     98.08        29           2       15.61
# ...

# %%
city_data_df.count()
# Out:
# City_ID       569
# City          569
# Country       566
# Date          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# dtype: int64

# %% [markdown]
# ## 5.1 Plotting Latitude vs. Temperature

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## 5.2 Plotting Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## 5.3 Plotting Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## 5.4 Plotting Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# # 6 Determining Correlations

# %% [markdown]
# ## 6.2  The Correlation Between Latitude and Maximum Temperature

# %%
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regresson on hemisphere weather data.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
#     print(f"The r-squared is: {rvalue:.3f}")
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City_ID                        13
# City              Arraial Do Cabo
# Country                        BR
# Date          2022-06-11 18:55:23
# Lat                      -22.9661
# Lng                      -42.0278
# Max Temp                    67.86
# Humidity                       83
# Cloudiness                    100
# Wind Speed                   9.22
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 564    False
# 565     True
# 566     True
# 567     True
# 568     True
# Name: Lat, Length: 569, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 1        1  San Patricio      US  2022-06-11 18:55:18  28.0170  -97.5169
# 2        2        Gadwal      IN  2022-06-11 18:55:19  16.2333   77.8000
# 3        3       Qaanaaq      GL  2022-06-11 18:51:47  77.4840  -69.3632
# 4        4         Phrae      TH  2022-06-11 18:55:19  18.0833  100.0000
# 5        5         Tiksi      RU  2022-06-11 18:55:20  71.6872  128.8694
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 1     98.08        29           2       15.61
# 2     84.70        57          94       16.67
# 3     30.24        72         100        2.37
# 4     72.10        91          80        2.42
# 5     37.87        76          94        7.18

# %%
# Create Northern Hemisphere DataFrame
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 1        1  San Patricio      US  2022-06-11 18:55:18  28.0170  -97.5169
# 2        2        Gadwal      IN  2022-06-11 18:55:19  16.2333   77.8000
# 3        3       Qaanaaq      GL  2022-06-11 18:51:47  77.4840  -69.3632
# 4        4         Phrae      TH  2022-06-11 18:55:19  18.0833  100.0000
# 5        5         Tiksi      RU  2022-06-11 18:55:20  71.6872  128.8694
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 1     98.08        29           2       15.61
# 2     84.70        57          94       16.67
# 3     30.24        72         100        2.37
# 4     72.10        91          80        2.42
# 5     37.87        76          94        7.18

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere (Latitude on the X axis and Max Temp on Y axis)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature', 'Max Temp',(-50,80))

# %% [markdown]
# There is a direct correlation between the latitude and maximum temperature. The correlation coefficients are strong for both hemispheres. With each degree change in latitude there is a change in temperature.

# %% [markdown]
# ## 6.3 The Correlation Between Latitude and (%) Humidity.

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity','% Humidity',(40,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity','% Humidity', (-50, 10))

# %% [markdown]
# Both hemispheres have very low correlation coefficients. There is no real relationship between humidity and latitude, although there seems to be more variablity in the Northern hemisphere than the Southern hemisphere.

# %% [markdown]
# ## 6.4 The Correlation Between Latitude and (%) Cloudiness

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness','% Cloudiness', (10, 55))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness','% Cloudiness', (-50,60))

# %% [markdown]
# Both hemispheres have low correlation coefficients. There is no relationship between the level of cloudiness and latitude.

# %% [markdown]
# ## 6.5 The Correlation Between Latitude and Wind Speed

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed','Wind Speed (mph)', (40,32))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed','Wind Speed (mph)', (-50,17))

# %% [markdown]
# Both hemispheres have low correlation coefficients. There is no relationship between wind speed and latitude. There seems to be more variablity in the Northern hemisphere than the Southern hemisphere.
